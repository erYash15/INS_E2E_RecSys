# %%
import pandas as pd

# %%
df = pd.read_csv('test_data/devices/part-00000-cdb2cdd7-9d14-4000-b947-4d0475444217-c000.csv')

# %%
df
# Out:
#                                    deviceid platform os_version  \
# 0      197b123e-eb9e-4fc1-a32d-aa86aaea425e  ANDROID         13
# 1      3c33c537-7c6c-40f5-835c-f997e883cae2  ANDROID         13
# 2      6c7be5d0-d4d8-469f-91be-8055021ceef9  ANDROID         12
# 3      0801af66-0a6f-4fdd-82a9-c2b15757b8f5  ANDROID        7.0
# 4      78b3c7a7-5881-42dc-9f8e-b4fc27f94360  ANDROID         13
# ...                                     ...      ...        ...
# 10395  2f2c7f12-919e-4692-9cf2-e1ee90238958  ANDROID         12
# 10396  3e78edec-c369-490b-8a12-35b00b8ece36  ANDROID         12
# 10397  b2c0071d-2b86-41fc-b0e3-5689e9aedef1  ANDROID         10
# 10398  0eaa96ab-7b42-446f-a877-60aaf70dc144  ANDROID         12
# 10399  017120da-5a11-4139-a438-97906a941a46  ANDROID         12
#
#                              model  networkType district  \
# 0                              NaN           4G      NaN
# 1                              NaN           4G      NaN
# ...

# %%
event_df = pd.read_csv('test_data/event/part-00000-7e210b01-29d8-430f-988f-d3e3b34da614-c000.csv')

# %%
event_df[event_df['deviceId'] == '7cb933f6-0a5b-477e-bb5d-42eb4b771970']
# Out:
#                                     deviceId       event_type  eventTimestamp  \
# 0       7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1689189015000
# 479     7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1689189376000
# 5444    7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1689189918000
# 6537    7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1689189877000
# 7908    7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1689189190000
# ...                                      ...              ...             ...
# 865406  7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1690191589000
# 867375  7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1690191011000
# 868577  7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1690195090000
# 879166  7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1687891006000
# 884125  7cb933f6-0a5b-477e-bb5d-42eb4b771970  TimeSpent-Front   1687891282000
#
# ...

# %%
import csv

# %%
path = "test_data/training_content/part-00000-a34a1545-5cf1-47b9-93c2-29c1d3f0bfb7-c000.csv"
rows = []
with open(path, newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    for row in reader:
        try:
            rows.append(row)
        except:
            print(row)
        
print("Number of rows loaded:", len(rows))
print("Max columns in a row:", max(len(r) for r in rows))
# Out:
# Number of rows loaded: 14636
# Max columns in a row: 22

# %%
import pandas as pd

# Convert all rows to a DataFrame
df = pd.DataFrame(rows)

# %%
rows[0]
# Out:
# ['hashid',
#  'title',
#  'content',
#  'newsType',
#  'author',
#  'categories',
#  'hashtags',
#  'newsDistrict',
#  'createdAt',
#  'updatedAt',
#  'newsLanguage',
#  'sourceName']

# %%
df[14].value_counts()
# Out:
# 14
# english                     528
# YouTube                     248
# The Indian Express          175
# Hindustan Times             162
# Twitter                     111
#                            ...
# SpotBoye                      1
# SpotboyE                      1
# Dailystar                     1
# 2023-07-18T13:24:11.000Z      1
# हिन्दुस्तान                   1
# Name: count, Length: 341, dtype: int64
